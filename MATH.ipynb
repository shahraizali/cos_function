# %% [markdown]
# ## Cosine Function
#
# (1-cos(2*x))/(x**2)

# %%
import matplotlib.pyplot as plt

# %%
# Import libraries 
import matplotlib.pyplot as plt 
import numpy as np 
import math
  
# Creating vectors X and Y 
x = np.linspace(-0.0000001, 0.0000001, 500) 
y = (1-np.cos(2*x))/(x**2)

print(np.vstack((x, y)).T)
# fig = plt.figure(figsize = (20, 5))
# plt.yscale('log')

# plt.grid(True)
# # Create the plot 
# plt.plot(x, y) 
  
# # Show the plot 
# plt.show()
# Out:
# [[-1.00000000e-07  1.99840144e+00]
#  [-9.95991984e-08  2.00332576e+00]
#  [-9.91983968e-08  1.99698218e+00]
#  [-9.87975952e-08  2.00184363e+00]
#  [-9.83967936e-08  1.99525122e+00]
#  [-9.79959920e-08  2.00004472e+00]
#  [-9.75951904e-08  2.00484982e+00]
#  [-9.71943888e-08  1.99791389e+00]
#  [-9.67935872e-08  2.00264405e+00]
#  [-9.63927856e-08  1.99543525e+00]
#  [-9.59919840e-08  2.00008468e+00]
#  [-9.55911824e-08  2.00474208e+00]
#  [-9.51903808e-08  1.99715470e+00]
#  [-9.47895792e-08  2.00172334e+00]
#  [-9.43887776e-08  1.99383626e+00]
#  [-9.39879760e-08  1.99830953e+00]
#  [-9.35871743e-08  2.00278646e+00]
#  [-9.31863727e-08  1.99448151e+00]
#  [-9.27855711e-08  1.99885383e+00]
#  [-9.23847695e-08  2.00322712e+00]
#  [-9.19839679e-08  1.99447932e+00]
#  [-9.15831663e-08  1.99873799e+00]
#  [-9.11823647e-08  2.00299464e+00]
#  [-9.07815631e-08  1.99377723e+00]
#  [-9.03807615e-08  1.99790840e+00]
#  [-8.99799599e-08  2.00203421e+00]
#  [-8.95791583e-08  2.00615404e+00]
# ...
